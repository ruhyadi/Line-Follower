# %%
from gym_line_follower.envs import LineFollowerEnv
env = LineFollowerEnv(gui=False, nb_cam_pts=8, max_track_err=0.3, max_time=100, randomize=True, obsv_type="points_latch")
obs = env.reset()
env.render(mode='human')
# Out:
# /home/didi/anaconda3/envs/gym/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# options=

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.5.2
